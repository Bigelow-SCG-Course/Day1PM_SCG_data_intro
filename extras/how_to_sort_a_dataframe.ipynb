# %% [markdown]
# This notebook shows you how to sort a dataframe and examine it in a Jupyter notebook.

# %%
import pandas as pd

# path to your csv here:

my_file = "../tbls/AG-910_assembly_stats_updated.csv"

# load your file into a dataframe:
df = pd.read_csv(my_file)

# look at the columns of your table
df.columns
# Out:
# Index(['Sample_ID', 'well_type', 'wga_cp', 'wgs_run_id', 'raw_read_count',
#        'final_contigs_count', 'final_assembly_length', 'max_contig_length',
#        'gc_content', 'checkM_estimated_completeness', 'number_multi_copy',
#        'checkM_classification', 'SSU_classification_1'],
#       dtype='object')

# %%
# sort your dataframe

# this should be one of your column names.  Replace 'final_assembly_length' with whatever value you want to sort by:
sort_value = 'final_assembly_length'

# do you want the sort to be ascending?  If you want it to be ascending (low to high), keep as is (True).  If not, change this to False
ascending = True

# How many rows do you want to look at after you've sorted your dataframe?
rowcount = 20

# sort command:
df.sort_values(by = sort_value, ascending = ascending).head(rowcount)
# Out:
#       Sample_ID well_type       wga_cp wgs_run_id  raw_read_count  \
# 176  AG-910-H09   No drop    15.352778     AG-910          305527
# 47   AG-910-B24   No drop     9.746330     AG-910          109574
# 51   AG-910-C04    1 cell  2829.092508     AG-910           81745
# 132  AG-910-F13    1 cell    16.501651     AG-910          375716
# 170  AG-910-H03   No drop    11.968250     AG-910           55529
# 73   AG-910-D02    1 cell    15.352778     AG-910          210511
# 161  AG-910-G18    1 cell    15.352778     AG-910          342513
# 210  AG-910-I19    1 cell    15.352778     AG-910          575017
# 333  AG-910-N22    1 cell    15.693058     AG-910          129453
# 72   AG-910-D01   No drop    15.352778     AG-910           94612
# 69   AG-910-C22    1 cell     8.106206     AG-910          451587
# 4    AG-910-A05    1 cell     8.659013     AG-910          210713
# 320  AG-910-N09    1 cell    10.116701     AG-910          568938
# 364  AG-910-P05    1 cell     8.146988     AG-910          376234
# 66   AG-910-C19    1 cell    15.352778     AG-910          335453
# 159  AG-910-G16    1 cell     7.188865     AG-910          529064
# 253  AG-910-K14    1 cell  3823.223174     AG-910          379389
# 368  AG-910-P09    1 cell    15.352778     AG-910          120268
# 341  AG-910-O06    1 cell     8.794916     AG-910          299924
# 309  AG-910-M22    1 cell     8.830109     AG-910          131331
#
#      final_contigs_count  final_assembly_length  max_contig_length  \
# 176                  1.0                 2094.0             2094.0
# 47                   1.0                 2199.0             2199.0
# 51                   1.0                 2311.0             2311.0
# 132                  1.0                 2315.0             2315.0
# 170                  1.0                 2561.0             2561.0
# 73                   1.0                 2625.0             2625.0
# 161                  1.0                 2721.0             2721.0
# 210                  1.0                 2943.0             2943.0
# 333                  1.0                 2960.0             2960.0
# 72                   1.0                 3215.0             3215.0
# 69                   1.0                 3251.0             3251.0
# 4                    1.0                 4106.0             4106.0
# 320                  1.0                 4279.0             4279.0
# 364                  1.0                 4343.0             4343.0
# 66                   2.0                 4397.0             2368.0
# 159                  1.0                 5058.0             5058.0
# 253                  2.0                 5167.0             2746.0
# 368                  1.0                 5317.0             5317.0
# 341                  2.0                 5400.0             2911.0
# 309                  1.0                 5557.0             5557.0
#
#      gc_content  checkM_estimated_completeness  number_multi_copy  \
# 176   47.277937                            0.0                0.0
# 47    68.894952                            0.0                0.0
# 51    65.296408                            0.0                0.0
# 132   31.447084                            0.0                0.0
# 170   63.529871                            0.0                0.0
# 73    61.676190                            0.0                0.0
# 161   60.235208                            0.0                0.0
# 210   59.972817                            0.0                0.0
# 333   64.391892                            0.0                0.0
# 72    63.888025                            0.0                0.0
# 69    37.803753                            0.0                0.0
# 4     39.892840                            0.0                0.0
# 320   37.041365                            0.0                0.0
# 364   34.285056                            0.0                0.0
# 66    63.042984                            0.0                0.0
# 159   46.065639                            0.0                0.0
# 253   64.292626                            0.0                0.0
# 368   60.899003                            0.0                0.0
# 341   29.296296                            0.0                0.0
# 309   65.089077                            0.0                0.0
#
#     checkM_classification  SSU_classification_1
# 176         NA;unresolved  no SSU regions found
# 47          NA;unresolved  no SSU regions found
# 51          NA;unresolved  no SSU regions found
# 132         NA;unresolved  no SSU regions found
# 170         NA;unresolved  no SSU regions found
# 73          NA;unresolved  no SSU regions found
# 161         NA;unresolved  no SSU regions found
# 210         NA;unresolved  no SSU regions found
# 333         NA;unresolved  no SSU regions found
# 72          NA;unresolved  no SSU regions found
# 69          NA;unresolved  no SSU regions found
# 4           NA;unresolved  no SSU regions found
# 320         NA;unresolved  no SSU regions found
# 364         NA;unresolved  no SSU regions found
# 66          NA;unresolved  no SSU regions found
# 159         NA;unresolved  no SSU regions found
# 253         NA;unresolved  no SSU regions found
# 368         NA;unresolved  no SSU regions found
# 341         NA;unresolved  no SSU regions found
# 309         NA;unresolved  no SSU regions found
